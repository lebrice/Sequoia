# %%
import wandb
api = wandb.Api()
import wandb
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
from sklearn import preprocessing
# %matplotlib inline

# %%
#SSCL 0.2

# %%
# Project is specified by <entity/project-name>
runs = api.runs("oleksost/SSCL_6_test_005")
methods_names = ['sup','sup_ewc','ict', 'ict_ewc', 'simclr', 'simclr_ewc',
                 'simclr_etached', 'simclr_ewc_detached', 'simclr_ict', 'simclr_ict_ewc']

# %%
runs_names = defaultdict(list)
run_names = []
for run in runs: 
    try:
        if run.config['use_accuracy_as_metric']:
            runs_names[run.config['config']['run_name']].append(run)
    except KeyError:
        pass

# %%
runs_names
# Out:
# defaultdict(list,
#             {'simclr_ict_ewc_accmetr': [<Run oleksost/SSCL_6_test_005/iitrdnbq (finished)>,
#               <Run oleksost/SSCL_6_test_005/2wtjpzfr (finished)>,
#               <Run oleksost/SSCL_6_test_005/2yxibb57 (finished)>],
#              'simclr_etached_accmetr': [<Run oleksost/SSCL_6_test_005/3f9c09la (finished)>,
#               <Run oleksost/SSCL_6_test_005/2mvm9eyw (finished)>,
#               <Run oleksost/SSCL_6_test_005/n2qfolx7 (finished)>],
#              'simclr_ict_accmetr': [<Run oleksost/SSCL_6_test_005/3dyhefd2 (finished)>,
#               <Run oleksost/SSCL_6_test_005/1vhgmkts (finished)>,
#               <Run oleksost/SSCL_6_test_005/1mbopjk9 (finished)>],
#              'simclr_ewc_detached_accmetr': [<Run oleksost/SSCL_6_test_005/3au777z0 (finished)>,
#               <Run oleksost/SSCL_6_test_005/1yy5dpyz (finished)>,
#               <Run oleksost/SSCL_6_test_005/jh495pwv (finished)>],
#              'simclr_ewc_accmetr': [<Run oleksost/SSCL_6_test_005/m7oygtfu (finished)>,
#               <Run oleksost/SSCL_6_test_005/h3yg59lc (finished)>,
#               <Run oleksost/SSCL_6_test_005/f4a1e0uf (finished)>],
#              'simclr_accmetr': [<Run oleksost/SSCL_6_test_005/rsvpkydo (finished)>,
#               <Run oleksost/SSCL_6_test_005/jcz0a1z1 (finished)>,
#               <Run oleksost/SSCL_6_test_005/bfe2ghv0 (finished)>],
#              'sup': [<Run oleksost/SSCL_6_test_005/1ycwnwbc (finished)>,
#               <Run oleksost/SSCL_6_test_005/2fuw8m90 (finished)>,
#               <Run oleksost/SSCL_6_test_005/2xi0xc0f (finished)>],
#              'sup_ewc': [<Run oleksost/SSCL_6_test_005/2whfolxv (finished)>,
#               <Run oleksost/SSCL_6_test_005/2phhjc08 (finished)>,
#               <Run oleksost/SSCL_6_test_005/1rysfk7n (finished)>],
#              'ict_loss_metric_3': [<Run oleksost/SSCL_6_test_005/25ps8rx4 (finished)>,
#               <Run oleksost/SSCL_6_test_005/1a232pc6 (finished)>,
#               <Run oleksost/SSCL_6_test_005/32kcbjw9 (finished)>],
#              'ict_ewc_loss_metric': [<Run oleksost/SSCL_6_test_005/3q4ie3u8 (finished)>,
#               <Run oleksost/SSCL_6_test_005/3f2y1qjf (finished)>,
#               <Run oleksost/SSCL_6_test_005/211b0gx4 (finished)>]})

# %%
column = 'Cumulative/Test/metrics/supervised/accuracy'
run = runs_names['simclr_ict_ewc_accmetr'][0]

# %%
history = run.scan_history(keys=[column])

# %%
losses = [print(row) for row in history]
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-fca33d6956e0> in <module>
# ----> 1 losses = [print(row) for row in history]
#
# <ipython-input-21-fca33d6956e0> in <listcomp>(.0)
# ----> 1 losses = [print(row) for row in history]
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in __next__(self)
#    1510             if self.page_offset >= self.max_step:
#    1511                 raise StopIteration()
# -> 1512             self._load_next()
#    1513
#    1514     next = __next__
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/__init__.py in wrapper(*args, **kwargs)
#      58         message = "Whoa, you found a bug."
#      59         try:
# ---> 60             return func(*args, **kwargs)
#      61         except requests.HTTPError as err:
#      62             raise CommError(err.response, err)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in wrapped_fn(*args, **kargs)
#     128         @functools.wraps(fn)
#     129         def wrapped_fn(*args, **kargs):
# --> 130             return retrier(*args, **kargs)
#     131         return wrapped_fn
#     132     return decorator
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      93         while True:
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#      97                     wandb.termlog('{} resolved after {}, resuming normal operation.'.format(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in _load_next(self)
#    1534         }
#    1535
# -> 1536         res = self.client.execute(self.QUERY, variable_values=variables)
#    1537         res = res['project']['run']['sampledHistory']
#    1538         self.rows = res[0]
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in wrapped_fn(*args, **kargs)
#     128         @functools.wraps(fn)
#     129         def wrapped_fn(*args, **kargs):
# --> 130             return retrier(*args, **kargs)
#     131         return wrapped_fn
#     132     return decorator
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      93         while True:
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#      97                     wandb.termlog('{} resolved after {}, resuming normal operation.'.format(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in execute(self, *args, **kwargs)
#      89         retryable_exceptions=(RetryError, requests.RequestException))
#      90     def execute(self, *args, **kwargs):
# ---> 91         return self._client.execute(*args, **kwargs)
#      92
#      93
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in execute(self, document, *args, **kwargs)
#      50             self.validate(document)
#      51
# ---> 52         result = self._get_result(document, *args, **kwargs)
#      53         if result.errors:
#      54             raise Exception(str(result.errors[0]))
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in _get_result(self, document, *args, **kwargs)
#      58     def _get_result(self, document, *args, **kwargs):
#      59         if not self.retries:
# ---> 60             return self.transport.execute(document, *args, **kwargs)
#      61
#      62         last_exception = None
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/transport/requests.py in execute(self, document, variable_values, timeout)
#      36             data_key: payload
#      37         }
# ---> 38         request = requests.post(self.url, **post_args)
#      39         request.raise_for_status()
#      40
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     350             context.load_default_certs()
#     351
# --> 352         self.sock = ssl_wrap_socket(
#     353             sock=conn,
#     354             keyfile=self.key_file,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     368     ) or IS_SECURETRANSPORT:
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#     372         warnings.warn(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
# --> 487                 if not util.wait_for_read(sock, sock.gettimeout()):
#     488                     raise timeout("select timed out")
#     489                 continue
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
for row in history:
    print(row)
    if column in row.keys():
        print(row[column])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-0fd1dcafe762> in <module>
# ----> 1 for row in history:
#       2     print(row)
#       3     if column in row.keys():
#       4         print(row[column])
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in __next__(self)
#    1510             if self.page_offset >= self.max_step:
#    1511                 raise StopIteration()
# -> 1512             self._load_next()
#    1513
#    1514     next = __next__
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/__init__.py in wrapper(*args, **kwargs)
#      58         message = "Whoa, you found a bug."
#      59         try:
# ---> 60             return func(*args, **kwargs)
#      61         except requests.HTTPError as err:
#      62             raise CommError(err.response, err)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in wrapped_fn(*args, **kargs)
#     128         @functools.wraps(fn)
#     129         def wrapped_fn(*args, **kargs):
# --> 130             return retrier(*args, **kargs)
#     131         return wrapped_fn
#     132     return decorator
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      93         while True:
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#      97                     wandb.termlog('{} resolved after {}, resuming normal operation.'.format(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in _load_next(self)
#    1534         }
#    1535
# -> 1536         res = self.client.execute(self.QUERY, variable_values=variables)
#    1537         res = res['project']['run']['sampledHistory']
#    1538         self.rows = res[0]
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in wrapped_fn(*args, **kargs)
#     128         @functools.wraps(fn)
#     129         def wrapped_fn(*args, **kargs):
# --> 130             return retrier(*args, **kargs)
#     131         return wrapped_fn
#     132     return decorator
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      93         while True:
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#      97                     wandb.termlog('{} resolved after {}, resuming normal operation.'.format(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in execute(self, *args, **kwargs)
#      89         retryable_exceptions=(RetryError, requests.RequestException))
#      90     def execute(self, *args, **kwargs):
# ---> 91         return self._client.execute(*args, **kwargs)
#      92
#      93
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in execute(self, document, *args, **kwargs)
#      50             self.validate(document)
#      51
# ---> 52         result = self._get_result(document, *args, **kwargs)
#      53         if result.errors:
#      54             raise Exception(str(result.errors[0]))
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in _get_result(self, document, *args, **kwargs)
#      58     def _get_result(self, document, *args, **kwargs):
#      59         if not self.retries:
# ---> 60             return self.transport.execute(document, *args, **kwargs)
#      61
#      62         last_exception = None
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/transport/requests.py in execute(self, document, variable_values, timeout)
#      36             data_key: payload
#      37         }
# ---> 38         request = requests.post(self.url, **post_args)
#      39         request.raise_for_status()
#      40
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     298     def connect(self):
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#     302
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     154
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %%
history

# %%
runs_res = defaultdict()
column = 'Cumulative/Test/metrics/supervised/accuracy'
step = 'task/currently_learned_task'
for k,runs in runs_names.items():
    print(k)
    res=[]
    for run in runs:
        history = run.scan_history(keys=column)
        for row in history: 
            if column in row.keys():
                print(row[step],row[column])   
                res.append([row[step],row[column]])
    res = pd.DataFrame(res, columns=[step,column]).set_index(step)
    res.reset_index(inplace=True)
    res = res.groupby(step)[column].apply(list)
    runs_res[k]=res
# Out:
# simclr_ict_ewc_accmetr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-7b03c901918a> in <module>
#       7     for run in runs:
#       8         history = run.scan_history(keys=[column])
# ----> 9         for row in history:
#      10             if column in row.keys():
#      11                 print(row[step],row[column])
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in __next__(self)
#    1510             if self.page_offset >= self.max_step:
#    1511                 raise StopIteration()
# -> 1512             self._load_next()
#    1513
#    1514     next = __next__
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/__init__.py in wrapper(*args, **kwargs)
#      58         message = "Whoa, you found a bug."
#      59         try:
# ---> 60             return func(*args, **kwargs)
#      61         except requests.HTTPError as err:
#      62             raise CommError(err.response, err)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in wrapped_fn(*args, **kargs)
#     128         @functools.wraps(fn)
#     129         def wrapped_fn(*args, **kargs):
# --> 130             return retrier(*args, **kargs)
#     131         return wrapped_fn
#     132     return decorator
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      93         while True:
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#      97                     wandb.termlog('{} resolved after {}, resuming normal operation.'.format(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in _load_next(self)
#    1534         }
#    1535
# -> 1536         res = self.client.execute(self.QUERY, variable_values=variables)
#    1537         res = res['project']['run']['sampledHistory']
#    1538         self.rows = res[0]
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in wrapped_fn(*args, **kargs)
#     128         @functools.wraps(fn)
#     129         def wrapped_fn(*args, **kargs):
# --> 130             return retrier(*args, **kargs)
#     131         return wrapped_fn
#     132     return decorator
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      93         while True:
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#      97                     wandb.termlog('{} resolved after {}, resuming normal operation.'.format(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in execute(self, *args, **kwargs)
#      89         retryable_exceptions=(RetryError, requests.RequestException))
#      90     def execute(self, *args, **kwargs):
# ---> 91         return self._client.execute(*args, **kwargs)
#      92
#      93
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in execute(self, document, *args, **kwargs)
#      50             self.validate(document)
#      51
# ---> 52         result = self._get_result(document, *args, **kwargs)
#      53         if result.errors:
#      54             raise Exception(str(result.errors[0]))
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in _get_result(self, document, *args, **kwargs)
#      58     def _get_result(self, document, *args, **kwargs):
#      59         if not self.retries:
# ---> 60             return self.transport.execute(document, *args, **kwargs)
#      61
#      62         last_exception = None
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/transport/requests.py in execute(self, document, variable_values, timeout)
#      36             data_key: payload
#      37         }
# ---> 38         request = requests.post(self.url, **post_args)
#      39         request.raise_for_status()
#      40
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/http/client.py in getresponse(self)
#    1320         try:
#    1321             try:
# -> 1322                 response.begin()
#    1323             except ConnectionError:
#    1324                 self.close()
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
runs_res = defaultdict()
column = 'Cumulative/Test/metrics/supervised/accuracy'
step = 'task/currently_learned_task'
for k,runs in runs_names.items():
    print(k)
    res=[]
    for run in runs:
        history = run.scan_history()
        print(history.)
# Out:
# simclr_ict
# <wandb.apis.public.HistoryScan object at 0x1177f3700>
# <wandb.apis.public.HistoryScan object at 0x1177f30a0>
# <wandb.apis.public.HistoryScan object at 0x1177f3700>
# <wandb.apis.public.HistoryScan object at 0x117500460>
# <wandb.apis.public.HistoryScan object at 0x1177f3700>
# <wandb.apis.public.HistoryScan object at 0x117500460>
# <wandb.apis.public.HistoryScan object at 0x11754a430>
# <wandb.apis.public.HistoryScan object at 0x117500460>
# <wandb.apis.public.HistoryScan object at 0x11754a430>
# simclr_ewc
# <wandb.apis.public.HistoryScan object at 0x103734b20>
# <wandb.apis.public.HistoryScan object at 0x117696190>
# <wandb.apis.public.HistoryScan object at 0x103734f70>
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-4dba8be38d32> in <module>
#       6     res=[]
#       7     for run in runs:
# ----> 8         history = run.scan_history()
#       9         print(history)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/__init__.py in wrapper(*args, **kwargs)
#      58         message = "Whoa, you found a bug."
#      59         try:
# ---> 60             return func(*args, **kwargs)
#      61         except requests.HTTPError as err:
#      62             raise CommError(err.response, err)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in scan_history(self, keys, page_size, min_step, max_step)
#     877             An iterable collection over history records (dict).
#     878         """
# --> 879         lastStep = self.lastHistoryStep
#     880         # set defaults for min/max step
#     881         if min_step is None:
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in lastHistoryStep(self)
#     918         }
#     919         ''')
# --> 920         response = self._exec(query)
#     921         if response is None or response.get('project') is None \
#     922                 or response['project'].get('run') is None or \
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in _exec(self, query, **kwargs)
#     771                      'project': self.project, 'name': self.id}
#     772         variables.update(kwargs)
# --> 773         return self.client.execute(query, variable_values=variables)
#     774
#     775     def _sampled_history(self, keys, x_axis="_step", samples=500):
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in wrapped_fn(*args, **kargs)
#     128         @functools.wraps(fn)
#     129         def wrapped_fn(*args, **kargs):
# --> 130             return retrier(*args, **kargs)
#     131         return wrapped_fn
#     132     return decorator
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      93         while True:
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#      97                     wandb.termlog('{} resolved after {}, resuming normal operation.'.format(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/wandb/apis/public.py in execute(self, *args, **kwargs)
#      89         retryable_exceptions=(RetryError, requests.RequestException))
#      90     def execute(self, *args, **kwargs):
# ---> 91         return self._client.execute(*args, **kwargs)
#      92
#      93
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in execute(self, document, *args, **kwargs)
#      50             self.validate(document)
#      51
# ---> 52         result = self._get_result(document, *args, **kwargs)
#      53         if result.errors:
#      54             raise Exception(str(result.errors[0]))
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/client.py in _get_result(self, document, *args, **kwargs)
#      58     def _get_result(self, document, *args, **kwargs):
#      59         if not self.retries:
# ---> 60             return self.transport.execute(document, *args, **kwargs)
#      61
#      62         last_exception = None
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/gql/transport/requests.py in execute(self, document, variable_values, timeout)
#      36             data_key: payload
#      37         }
# ---> 38         request = requests.post(self.url, **post_args)
#      39         request.raise_for_status()
#      40
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     350             context.load_default_certs()
#     351
# --> 352         self.sock = ssl_wrap_socket(
#     353             sock=conn,
#     354             keyfile=self.key_file,
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     368     ) or IS_SECURETRANSPORT:
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#     372         warnings.warn(
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
# --> 487                 if not util.wait_for_read(sock, sock.gettimeout()):
#     488                     raise timeout("select timed out")
#     489                 continue
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/opt/anaconda3/envs/falr/lib/python3.8/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
run.summary.keys()
# Out:
# dict_keys(['lr', '_step', '_runtime', '_timestamp', 'Train/total_loss', 'Valid/total_loss', 'Cumul Accuracy [0]', 'Cumul Accuracy [1]', 'Cumul Accuracy [2]', 'Cumul Accuracy [3]', 'Cumul Accuracy [4]', 'KNN_per_task/avv_knn', 'Cumulative/total_loss', 'Valid/losses/EWC/total_loss', 'task/currently_learned_task', 'Task_losses/Task0/total_loss', 'Task_losses/Task1/total_loss', 'Task_losses/Task2/total_loss', 'Task_losses/Task3/total_loss', 'Task_losses/Task4/total_loss', 'KNN_per_task/knn_train_task_0', 'KNN_per_task/knn_train_task_1', 'KNN_per_task/knn_train_task_2', 'KNN_per_task/knn_train_task_3', 'KNN_per_task/knn_train_task_4', 'KNN_per_task/knn_valid_task_0', 'KNN_per_task/knn_valid_task_1', 'KNN_per_task/knn_valid_task_2', 'KNN_per_task/knn_valid_task_3', 'KNN_per_task/knn_valid_task_4', 'Train/losses/Train/total_loss', 'Valid/losses/SimCLR/total_loss', 'Cumulative/losses/Test/total_loss', 'Train/metrics/supervised/accuracy', 'Valid/metrics/supervised/accuracy', 'Train/metrics/supervised/n_samples', 'Valid/losses/supervised/total_loss', 'Valid/metrics/supervised/n_samples', 'Cumulative/metrics/supervised/accuracy', 'Cumulative/metrics/supervised/n_samples', 'Task_losses/Task0/losses/EWC/total_loss', 'Task_losses/Task1/losses/EWC/total_loss', 'Task_losses/Task2/losses/EWC/total_loss', 'Task_losses/Task3/losses/EWC/total_loss', 'Task_losses/Task4/losses/EWC/total_loss', 'Train/losses/Train/losses/EWC/total_loss', 'Verbose/knn_losses[0][0]/train/total_loss', 'Verbose/knn_losses[0][0]/valid/total_loss', 'Verbose/knn_losses[0][1]/train/total_loss', 'Verbose/knn_losses[0][1]/valid/total_loss', 'Verbose/knn_losses[0][2]/train/total_loss', 'Verbose/knn_losses[0][2]/valid/total_loss', 'Verbose/knn_losses[0][3]/train/total_loss', 'Verbose/knn_losses[0][3]/valid/total_loss', 'Verbose/knn_losses[0][4]/train/total_loss', 'Verbose/knn_losses[0][4]/valid/total_loss', 'Verbose/knn_losses[1][0]/train/total_loss', 'Verbose/knn_losses[1][0]/valid/total_loss', 'Verbose/knn_losses[1][1]/train/total_loss', 'Verbose/knn_losses[1][1]/valid/total_loss', 'Verbose/knn_losses[1][2]/train/total_loss', 'Verbose/knn_losses[1][2]/valid/total_loss', 'Verbose/knn_losses[1][3]/train/total_loss', 'Verbose/knn_losses[1][3]/valid/total_loss', 'Verbose/knn_losses[1][4]/train/total_loss', 'Verbose/knn_losses[1][4]/valid/total_loss', 'Verbose/knn_losses[2][0]/train/total_loss', 'Verbose/knn_losses[2][0]/valid/total_loss', 'Verbose/knn_losses[2][1]/train/total_loss', 'Verbose/knn_losses[2][1]/valid/total_loss', 'Verbose/knn_losses[2][2]/train/total_loss', 'Verbose/knn_losses[2][2]/valid/total_loss', 'Verbose/knn_losses[2][3]/train/total_loss', 'Verbose/knn_losses[2][3]/valid/total_loss', 'Verbose/knn_losses[2][4]/train/total_loss', 'Verbose/knn_losses[2][4]/valid/total_loss', 'Verbose/knn_losses[3][0]/train/total_loss', 'Verbose/knn_losses[3][0]/valid/total_loss', 'Verbose/knn_losses[3][1]/train/total_loss', 'Verbose/knn_losses[3][1]/valid/total_loss', 'Verbose/knn_losses[3][2]/train/total_loss', 'Verbose/knn_losses[3][2]/valid/total_loss', 'Verbose/knn_losses[3][3]/train/total_loss', 'Verbose/knn_losses[3][3]/valid/total_loss', 'Verbose/knn_losses[3][4]/train/total_loss', 'Verbose/knn_losses[3][4]/valid/total_loss', 'Verbose/knn_losses[4][0]/train/total_loss', 'Verbose/knn_losses[4][0]/valid/total_loss', 'Verbose/knn_losses[4][1]/train/total_loss', 'Verbose/knn_losses[4][1]/valid/total_loss', 'Verbose/knn_losses[4][2]/train/total_loss', 'Verbose/knn_losses[4][2]/valid/total_loss', 'Verbose/knn_losses[4][3]/train/total_loss', 'Verbose/knn_losses[4][3]/valid/total_loss', 'Verbose/knn_losses[4][4]/train/total_loss', 'Verbose/knn_losses[4][4]/valid/total_loss', 'Task_losses/Task0/losses/SimCLR/total_loss', 'Task_losses/Task1/losses/SimCLR/total_loss', 'Task_losses/Task2/losses/SimCLR/total_loss', 'Task_losses/Task3/losses/SimCLR/total_loss', 'Task_losses/Task4/losses/SimCLR/total_loss', 'Train/losses/Train/losses/SimCLR/total_loss', 'Cumulative/losses/Test/losses/EWC ...
