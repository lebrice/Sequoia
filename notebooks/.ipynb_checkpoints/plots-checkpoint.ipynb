# %%
import wandb
import numpy as np
import itertools
api = wandb.Api()
import wandb
import numpy as np
import pandas as pd
import matplotlib.cm as cm
from collections import defaultdict
import matplotlib.pyplot as plt
from sklearn import preprocessing
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

# %%
data1 = pd.read_csv('wandb_export_2020-05-30T13_52_23.553-04_00.csv').replace('undefined',0)
data2 = pd.read_csv('wandb_export_2020-05-30T13_53_01.332-04_00.csv').replace('undefined',0)
data3 = pd.read_csv('wandb_export_2020-05-30T13_53_44.056-04_00.csv').replace('undefined',0)

# %%
tasks = np.array([0,0,1,1,2,2,2,3,3,4,4,4])
data1['tasks']=tasks
data2['tasks']=tasks
data3['tasks']=tasks
cols = data1.columns
data1[cols] = data1[cols].apply(pd.to_numeric, errors='coerce')
data2[cols] = data2[cols].apply(pd.to_numeric, errors='coerce')
data3[cols] = data3[cols].apply(pd.to_numeric, errors='coerce')

# %%
d1 = data1.groupby('tasks')[data1.columns].max()
d2 = data2.groupby('tasks')[data2.columns].max()
d3 = data2.groupby('tasks')[data2.columns].max()

# %%
d = pd.concat([d1,d2,d3],axis=1)

d = d.drop('tasks',axis=1)
d = d.drop('Step',axis=1)

# %%
mean = d.groupby(by=d.columns, axis=1).mean()

# %%
std = d.groupby(by=d.columns, axis=1).std()

# %%
mean.columns
# Out:
# Index(['Name: ict_acc_metric_3 - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: ict_ewc_acc_metric - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: simclr_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: simclr_etached_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: simclr_ewc_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: simclr_ewc_detached_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: simclr_ict_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: simclr_ict_ewc_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: sup_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy',
#        'Name: sup_ewc_accmetr - Cumulative/losses/Test/losses/supervised/metrics/supervised/accuracy'],
#       dtype='object')

# %%
mean.columns = ['ict','ict+ewc','simclr','simclr detached','simclr+ewc','simclr detached+ewc','simclr+ict','simclr+ict+ewc','sup','sup+ewc']
std.columns = mean.columns

# %%
fig = plt.figure(figsize=(20,10))
# Set up Axes
ax = fig.add_subplot(111)
x = np.arange(len(mean))
colors = (n for n in ['tab:blue','tab:green','tab:orange','tab:red','tab:purple'])
colors_={}
line = (n for n in [(0,(5,5)), (0,(1,1)), (0,(3,10,1,10)), (0,(3,1,1,1,1,1)), '-'])
line_ = {}
for name in mean.columns:
    if 'ewc' in name:
        c = next(colors)
        l = next(line)
        colors_[name[:-4]] = c
        line_[name[:-4]] = l
        ax.plot(x,mean[name], color=c, linestyle=l, label=name)
        ax.fill_between(x, (mean[name]-std[name]), (mean[name]+std[name]), color=c, alpha=.1)


ax.legend(fontsize=15)
ax.margins(x=0)
ax.set_ylabel('Acc.', fontsize=18)
ax.set_xlabel('Task',fontsize=18)   
plt.xticks([0,1,2,3,4],fontsize=15)   
ax.tick_params(axis='both', which='major', direction='in', length=10, labelsize=12)

for i in range(0,5):
    ax.axvline(x=i*1, c='lightgrey', linewidth = 1)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.legend(fontsize=20)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fig.savefig('/Users/oleksostapenko/Projects/SSCL/notebooks/plots/005/005_ewc.png', bbox_inches='tight', dpi=300)

# %%
fig = plt.figure(figsize=(20,10))
# Set up Axes
ax = fig.add_subplot(111)
x = np.arange(len(mean))         
#colors = iter(cm.rainbow(np.linspace(0, 1, len(mean.columns))))
for name in mean.columns:
    if 'ewc' not in name:
        c=colors_[name]
        l=line_[name]
        ax.plot(x,mean[name], color=c, linestyle=l, label=name)
        ax.fill_between(x, (mean[name]-std[name]), (mean[name]+std[name]), color=c, alpha=.1)

    
ax.legend(fontsize=15)
ax.margins(x=0)
ax.set_ylabel('Acc.', fontsize=18)
ax.set_xlabel('Task',fontsize=18)   
plt.xticks([0,1,2,3,4],fontsize=15)   
ax.tick_params(axis='both', which='major', direction='in', length=10, labelsize=12)

for i in range(0,5):
    ax.axvline(x=i*1, c='lightgrey', linewidth = 1)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.legend(fontsize=20)

# %%
fig.savefig('/Users/oleksostapenko/Projects/SSCL/notebooks/plots/005/005_.png', bbox_inches='tight', dpi=300)
